# %% [markdown]
# # Git and GitHub Operations
# ### This notebook is for github and version control operations

# %%
# Mounting Google Drive
from google.colab import drive
from os.path import join
ROOT = '/content/drive'
print(ROOT)
drive.mount(ROOT)

# %cd /content/drive/My\ Drive/Colab Notebooks/ProjectData/FaceRecognition
# Out:
# /content/drive
# Mounted at /content/drive
# /content/drive/My Drive/Colab Notebooks/ProjectData/FaceRecognition

# %%
# !pwd
# Out:
# /content/drive/My Drive/Colab Notebooks/ProjectData/FaceRecognition

# %%
# !ls -la
# Out:
# total 31772
# drwx------ 2 root root     4096 Apr  2 18:13  CNNSave
# drwx------ 2 root root     4096 May 22 20:53  dataset
# drwx------ 2 root root     4096 Mar 31 17:39  dataset2
# drwx------ 2 root root     4096 Apr  2 18:02  dataset3
# drwx------ 2 root root     4096 Apr 15 14:13  dataset4
# drwx------ 2 root root     4096 May 22 20:51  datasetFriends
# -rw------- 1 root root    26382 Nov 30 15:42  DataSet_setup.ipynb
# -rw------- 1 root root    54578 May 12 15:59 'Environment_setup(suranjan).ipynb'
# -rw------- 1 root root    70099 May 10 09:04  FaceCNN_Aug.ipynb
# -rw------- 1 root root    95312 Apr 25 13:43  FaceCnnModel.ipynb
# drwx------ 2 root root     4096 Nov 30 15:43  face_detection_model
# -rw------- 1 root root   304327 May  9 20:27  faceInceptionV3_TransferLearning.ipynb
# -rw------- 1 root root   906784 May 24 09:25  faceVGG16_TransferLearning.ipynb
# drwx------ 2 root root     4096 Apr 16 12:19  filesBySouhardo
# drwx------ 2 root root     4096 Nov 30 15:43  .git
# -rw------- 1 root root       74 May 12 15:30  .gitignore
# -rw------- 1 root root    25358 May 24 09:26  Git_Operations.ipynb
# drwx------ 2 root root     4096 Nov 30 15:43  image
# -rw------- 1 root root   156179 Apr 27 18:17  ImageDetection.ipynb
# -rw------- 1 root root     8934 Apr 26 18:34  Image_Recognition.ipynb
# drwx------ 2 root root     4096 May 12 15:59  .ipynb_checkpoints
# drwx------ 2 root root     4096 Dec  3 20:22  models
# drwx------ 2 root root     4096 Nov 30 15:43  output
# drwx------ 2 root root     4096 Apr 16 12:17  pickle
# drwx------ 2 root root     4096 Apr 16 12:38  preview_data_aug
# drwx------ 2 root root     4096 Dec  3 20:23  __pycache__
# -rw------- 1 root root      254 Nov 30 15:42  README.md
# -rw------- 1 root root 30795471 May 22 07:39  Testing.ipynb
# drwx------ 2 root root     4096 May 10 09:11  testset
# -rw------- 1 root root    12723 Apr 27 18:17  Train_Image_Recognition_model.ipynb
# drwx------ 2 root root     4096 Dec  3 20:27  weights

# %%
# Run this always , cuz it sets the git user name and password in the VM instance
# !git config --global user.email "suranjandaw@gmail.com"
# !git config --global user.name "SuranjanDaw"

# %%
# !git status

# %%
# !git status

# %%
# !git diff

# %%
# !git log  --pretty --graph --oneline

# %%
# !git add .

# %%
# !git commit -m"Boosted the model accuracy of VGG16 from 89% to 91%. Added new metrics, Precision , Recall , F1 Score"
# Out:
# [main be46f53] Added new image augmentation code and it boosted the model accuracy of VGG16 from 77% to 89%
#  52 files changed, 3 insertions(+), 3 deletions(-)
#  rewrite Git_Operations.ipynb (79%)
#  rename {dataset => datasetFriends}/arpan/IMG-20180104-WA0004.jpg (100%)
#  rename {dataset => datasetFriends}/arpan/IMG-20180114-WA0040.jpg (100%)
#  rename {dataset => datasetFriends}/arpan/IMG-20180208-WA0000.jpg (100%)
#  rename {dataset => datasetFriends}/arpan/IMG-20180811-WA0022.jpg (100%)
#  rename {dataset => datasetFriends}/arpan/IMG-20180925-WA0019.jpg (100%)
#  rename {dataset => datasetFriends}/arpan/IMG-20200307-WA0016.jpg (100%)
#  rename {dataset => datasetFriends}/arpan/IMG-20200520-WA0004.jpg (100%)
#  rename {dataset => datasetFriends}/arpan/IMG-20200902-WA0007.jpg (100%)
#  rename {dataset => datasetFriends}/arpan/IMG-20200902-WA0015.jpg (100%)
#  rename {dataset => datasetFriends}/arpan/IMG_20181224_121707408_HDR.jpg (100%)
#  rename {dataset => datasetFriends}/arpan/IMG_20190210_155413235.jpg (100%)
#  rename {dataset => datasetFriends}/arpan/arpan1.jpg (100%)
#  rename {dataset => datasetFriends}/daw/1579346813359.jpg (100%)
#  rename {dataset => datasetFriends}/daw/1579422263936.jpg (100%)
#  rename {dataset => datasetFriends}/daw/IMG_20190829_202315156.jpg (100%)
#  rename {dataset => datasetFriends}/daw/IMG_20191111_113042192_BURST000_COVER_TOP.jpg (100%)
#  rename {dataset => datasetFriends}/daw/IMG_20200403_222608092.jpg (100%)
#  rename {dataset => datasetFriends}/daw/IMG_20200524_213142112.jpg (100%)
#  rename {dataset => datasetFriends}/daw/IMG_20200524_213302106.jpg (100%)
#  rename {dataset => datasetFriends}/daw/IMG_20200612_222328113_BURST000_COVER_TOP.jpg (100%)
#  rename {dataset => datasetFriends}/daw/IMG_20200704_100931392.jpg (100%)
#  rename {dataset => datasetFriends}/daw/IMG_20200722_235426989.jpg (100%)
#  rename {dataset => datasetFriends}/daw/IMG_20200723_230334639.jpg (100%)
#  rename {dataset => datasetFriends}/daw/IMG_20200902_162415615.jpg (100%)
#  rename {dataset => datasetFriends}/remon/IMG-20180811-WA0027.jpg (100%)
#  rename {dataset => datasetFriends}/remon/IMG-20181009-WA0000.jpg (100%)
#  rename {dataset => datasetFriends}/remon/IMG-20181015-WA0038.jpg (100%)
#  rename {dataset => datasetFriends}/remon/IMG-20181027-WA0016.jpg (100%)
#  rename {dataset => datasetFriends}/remon/IMG-20190130-WA0021.jpg (100%)
#  rename {dataset => datasetFriends}/remon/IMG-20190803-WA0002.jpg (100%)
#  rename {dataset => datasetFriends}/remon/IMG-20191028-WA0035.jpg (100%)
#  rename {dataset => datasetFriends}/remon/IMG-20191028-WA0044.jpg (100%)
#  rename {dataset => datasetFriends}/remon/IMG-20191028-WA0045.jpg (100%)
#  rename {dataset => datasetFriends}/remon/IMG-20191228-WA0018.jpg (100%)
#  rename {dataset => datasetFriends}/remon/IMG-20191231-WA0016.jpg (100%)
#  rename {dataset => datasetFriends}/remon/IMG-20200102-WA0005.jpg (100%)
#  rename {dataset => datasetFriends}/unknown/Nabaneeta-Dev-Sen.jpg (100%)
#  rename {dataset => datasetFriends}/unknown/Yash-Dasgupta.jpg (100%)
#  rename {dataset => datasetFriends}/unknown/dev-bengali.jpg (100%)
#  rename {dataset => datasetFriends}/unknown/images-_2__1.jpg (100%)
#  rename {dataset => datasetFriends}/unknown/images-_4_.jpg (100%)
#  rename {dataset => datasetFriends}/unknown/images.jpg (100%)
#  rename {dataset => datasetFriends}/unknown/jishu.jpg (100%)
#  rename {dataset => datasetFriends}/unknown/rahul-dev.jpg (100%)
#  rename {dataset => datasetFriends}/unknown/u1.jpg (100%)
#  rename {dataset => datasetFriends}/unknown/u2.jpg (100%)
#  rename {dataset => datasetFriends}/unknown/u4.jpg (100%)
#  rename {dataset => datasetFriends}/unknown/xx.jpg (100%)
#  rewrite faceVGG16_TransferLearning.ipynb (91%)
#  rewrite testset/BollyOutputVid.avi (99%)

# %%
# Run this if you want to delete unwanted Remote repositories
'''
# !git remote rm origin
'''

# %%
# !git remote -v
# Out:
# nerdf	https://a3ef1b2e51002584031c5752f3de26fb93c65c02@github.com/Nerd-iProject/FaceRecognition.git (fetch)
# nerdf	https://a3ef1b2e51002584031c5752f3de26fb93c65c02@github.com/Nerd-iProject/FaceRecognition.git (push)
# origin	https://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@github.com/SuranjanDaw/FaceRecognition.git (fetch)
# origin	https://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@github.com/SuranjanDaw/FaceRecognition.git (push)

# %%
# !git log --graph --pretty --oneline
# Out:
# * be46f53 (HEAD -> main) Added new image augmentation code and it boosted the model accuracy of VGG16 from 77% to 89%
# * f0d70c9 (origin/main) Added testing code
# *   597db49 Resolving Merge Conflicts
# |\
# | *   25ae138 new changes
# | |\
# | | * 73337e2 Created using Colaboratory
# | | * f3e0a6c Created using Colaboratory
# | * | eab1300 new changes added
# * | | f9bc441 Tweaks
# * | | efda3fe Added VGG16 and InceptionV3. Got 77% out-sample accuracy
# |/ /
# * | 592f678 new model training method added with better accuracy
# * | efbcde8 blah
# * | 7f98fe2 blah
# * | c1b2ad9 removed self-link
# * | 6fe70b0 removed self-link
# * | b663c7d (nerdf/main) removed self-link
# * | dca7654 new changes
# * | f8daf9a new changes
# * | eaaaff3 new changes
# * | 7cccdd1 new changes
# * | f8e4439 new changes
# * | af1c453 new changes
# * | 0ee369f new changes
# * | 7150b1b new changes
# * | 0d0fb9e new changes
# * | 5fb61bb new changes
# * | 133777f new changes
# * | 567d082 new changes
# * | 771a579 new changes
# * | a63682d new changes
# * | d627c3a new changes
# * | 3fc2e43 new changes
# * | f069a24 new changes
# * | e9db058 new changes
# * | 67b9cdc new changes
# * | a683deb new changes
# * | 57caa15 new changes
# * | 3b30bc1 new changes
# * | afefe95 new changes
# * | 01c257a new changes
# * | d2e03c7 new changes
# * | ae4f76f new changes
# * | 53ca467 new changes
# * | 83fc976 new changes
# * | 0353fb2 new changes
# * | c0e555d new changes
# * | 0827bf1 new changes
# * | 1181039 new changes
# * | 48c3c3a new changes
# * | 42e597f new changes
# * | 545118f new changes
# * | dfb88a8 new changes
# * | a2b0393 new changes
# * | e7beb4f new changes
# * | bb56f32 new changes
# * | f2cb17b new changes
# * | 3818102 new changes
# * | 7cb85b3 new changes
# * | 0b14cc7 More data added
# * | bb89e47 More data added
# * | 96968a1 More data added
# * | dab9f46 More data added
# * | b3f9e23 More data added
# * | 754c3ea More data added
# * | 48e69bf More data added
# * | 8225956 More data added
# * | f91a1df More data added
# * | 87152da More data added
# * | ea5c57a More data added
# * | 7a5c83b More data added
# * | de37bd6 More data added
# * | 68fae45 More data added
# * | 1fcdbf0 More data added
# * | 5f866fc More data added
# * | 3b05f78 More data added
# * | 620ffbf More data added
# * | cec2c3f More data added
# |/
# * bea8850 Updated DataSetup and Env_setup
# * 785e98a Added untracked ipython/colab notebooks
# * 156905b The dataset is trained with new data. Results: Confidence score increased
# * f86d358 More data added
# * 85fb770 Image recognition integrated
# *   297ba50 merging pull
# |\
# | * b7d02dc Importing DataSet from git to google drive and setting project structure
# * | 01542f3 Image detection integrated with 128D embedding generated
# |/
# * f848202 output and image folder added with test image
# * dfae9ee face_detection_model (caffe)added and 128-D embedder added
# * b7bfb1c dataset added
# * 6cbdb5c Environment Setup done
# * 8b21f8c Created using Colaboratory
# * 75cde1d Created using Colaboratory
# * 96772a2 Create README.md

# %%
# run this if your remote path is not set.
git_user = 'SuranjanDaw'
git_repo = 'FaceRecognition'
git_token_Daw_to_Nerdi = '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'
GIT_PATH = "https://" + git_token_Daw_to_Nerdi + "@github.com/" + git_user + "/" + git_repo + ".git"
print("GIT_PATH: ", GIT_PATH)
# Out:
# GIT_PATH:  https://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@github.com/SuranjanDaw/FaceRecognition.git

# %%
# run this if your remote path is not set.
# !git remote add origin '{GIT_PATH}'

# %%
# If some error is coming then you must assume that the Github Personal Token has expired for some reason and needs to replaced with a new one
# !git pull origin main
# Out:
# From https://github.com/SuranjanDaw/FaceRecognition
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# If some error is coming then you must assume that the Github Personal Token has expired for some reason and needs to replaced with a new one
# !git push origin main
# Out:
# Counting objects: 7, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (7/7), 22.08 MiB | 4.57 MiB/s, done.
# Total 7 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/SuranjanDaw/FaceRecognition.git
#    f0d70c9..be46f53  main -> main
